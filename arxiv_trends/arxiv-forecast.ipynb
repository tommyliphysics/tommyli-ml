# %%
import pandas as pd

# %%
title_keywords_monthly_title_data = pd.read_csv('title_keywords_monthly_title_data.csv')
title_keywords_monthly_title_data
# Out:
#      months_since_Jan_2000   quantum     model  superconducting      spin  \
# 0                        0  0.086957  0.112648         0.100791  0.088933
# 1                        1  0.118774  0.124521         0.084291  0.095785
# 2                        2  0.133568  0.117750         0.098418  0.086116
# 3                        3  0.127542  0.138632         0.085028  0.075786
# 4                        4  0.095076  0.147708         0.062818  0.093379
# ..                     ...       ...       ...              ...       ...
# 286                    286  0.120798  0.081933         0.063025  0.084559
# 287                    287  0.124358  0.079293         0.061609  0.081004
# 288                    288  0.115882  0.078824         0.058824  0.067647
# 289                    289  0.125442  0.080094         0.061249  0.073616
# 290                    290  0.116897  0.095112         0.059511  0.090329
#
#      magnetic    effect  electron  dimensional     phase  ...    torque  \
# ...

# %%
title_keywords_monthly_abstract_data = pd.read_csv('title_keywords_monthly_abstract_data.csv')
title_keywords_monthly_abstract_data
# Out:
#      months_since_Jan_2000   quantum     model  superconducting      spin  \
# 0                        0  0.181818  0.377470         0.162055  0.189723
# 1                        1  0.208812  0.373563         0.143678  0.185824
# 2                        2  0.179262  0.393673         0.147627  0.198594
# 3                        3  0.186691  0.375231         0.131238  0.205176
# 4                        4  0.183362  0.348048         0.113752  0.191851
# ..                     ...       ...       ...              ...       ...
# 286                    286  0.297794  0.366597         0.110819  0.204307
# 287                    287  0.300627  0.364518         0.120936  0.237307
# 288                    288  0.278824  0.370000         0.101176  0.200588
# 289                    289  0.299176  0.368669         0.109541  0.218492
# 290                    290  0.285866  0.388948         0.115303  0.218385
#
#      magnetic    effect  electron  dimensional     phase  ...    torque  \
# ...

# %%
abstract_keywords_monthly_abstract_data = pd.read_csv('abstract_keywords_monthly_abstract_data.csv')
abstract_keywords_monthly_abstract_data
# Out:
#      months_since_Jan_2000    system     state     study   results     model  \
# 0                        0  0.288538  0.294466  0.326087  0.343874  0.377470
# 1                        1  0.285441  0.321839  0.354406  0.350575  0.373563
# 2                        2  0.311072  0.342707  0.312830  0.326889  0.393673
# 3                        3  0.290203  0.312384  0.323475  0.297597  0.375231
# 4                        4  0.297114  0.288625  0.319185  0.293718  0.348048
# ..                     ...       ...       ...       ...       ...       ...
# 286                    286  0.389181  0.388130  0.399160  0.377626  0.366597
# 287                    287  0.397604  0.379350  0.389047  0.384484  0.364518
# 288                    288  0.429412  0.367647  0.408824  0.355294  0.370000
# 289                    289  0.402827  0.398115  0.391048  0.392815  0.368669
# 290                    290  0.414984  0.386823  0.395324  0.334750  0.388948
#
# ...

# %% [markdown]
# Let's set up the training and testing data. I'll use the last 20 months for forecasting.

# %%
train = title_keywords_monthly_title_data.iloc[:271]
test = title_keywords_monthly_title_data.iloc[271:]
